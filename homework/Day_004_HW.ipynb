# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Aug 29 20:44:49 2019

@author: SUPRA
"""
import os
import numpy as py
import pandas as pd

#檔案路徑
dir_data = "D:\\3rd-AI\example\d4"
#讀取檔案
f_app = os.path.join(dir_data,'HomeCredit_columns_description.csv')
print('Path of read in data: %s' %(f_app))
app_train = pd.read_csv(f_app)
#抓取檔案row、column數目
data_shape = app_train.shape#返回型態為tuple
data_row = str(data_shape[0])
data_col =  str(data_shape[1])
print('row have:' + data_row)
print('column have:' + data_col)

#列出所有欄位
print(app_train.columns)

#擷取部分資料
df_some = app_train.Row
print(df_some)
# Out:
# Path of read in data: D:\3rd-AI\example\d4\HomeCredit_columns_description.csv
# row have:205
# column have:7
# Index(['Unnamed: 0', 'Table', 'Row', 'Description', 'Special', 'Unnamed: 5',
#        'Unnamed: 6'],
#       dtype='object')
# 0                       SK_ID_CURR
# 1                           TARGET
# 2               NAME_CONTRACT_TYPE
# 3                      CODE_GENDER
# 4                     FLAG_OWN_CAR
# 5                  FLAG_OWN_REALTY
# 6                     CNT_CHILDREN
# 7                 AMT_INCOME_TOTAL
# 8                       AMT_CREDIT
# 9                      AMT_ANNUITY
# 10                 AMT_GOODS_PRICE
# 11                 NAME_TYPE_SUITE
# 12                NAME_INCOME_TYPE
# 13             NAME_EDUCATION_TYPE
# 14              NAME_FAMILY_STATUS
# 15               NAME_HOUSING_TYPE
# 16      REGION_POPULATION_RELATIVE
# 17                      DAYS_BIRTH
# 18                   DAYS_EMPLOYED
# 19               DAYS_REGISTRATION
# ...
